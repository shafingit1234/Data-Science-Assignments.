# %%
# Question: Explain why we have to use the Exception class while creating a custom exception.
ans = """ 
    If we talk about in built exceptions, they are just regular classes,
    that inherit from the exception class. For example, specific exception classes
    like ZeroDivisionError, IndexError etc are all children of parent class called Exception.
    
    Similar to in-built exception classes, while making custom exception classes,
    we should make sure that our classes are inheriting Exception class directly or indirectly.
    
    It is important to use Exception reference since then only we will be able to use 'raise' keyword,
    that plays a crucial role while handling exception.
    If custom exceptions do not inherit Exception class then our program can stop abnormaly by throwing and exception,
    that goes like this: TypeError: exceptions must derive from BaseException.
    Such error can occur if you have raised an error without refering to Exception class.
    Example given below.
"""
class InvalidAgeException():
    "Raised when the input value is less than 18"
    pass
try:
    input_num = int(input("Enter a number: "))
    if input_num < number:
        raise InvalidAgeException
    else:
        print("Eligible to Vote")
        
except InvalidAgeException:
    print("Exception occurred: Invalid Age")
# Out:
# Enter a number:  10
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 23
#      22 if input_num < number:
# ---> 23     raise InvalidAgeException
#      24 else:
#
# TypeError: exceptions must derive from BaseException
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 27
#      24     else:
#      25         print("Eligible to Vote")
# ---> 27 except InvalidAgeException:
#      28     print("Exception occurred: Invalid Age")
#
# TypeError: catching classes that do not inherit from BaseException is not allowed

# %%
# Question: Write a python program to print Python Exception Hierarchy.
ans = """ To print the tree hierarchy, we can use inspect module of python.
The Inspect module is used for getting information about objects like modules, classes,
methods, functions and objects of the program.
"""
# Code:
import inspect as ipt;
def print_sub_classes(classes , ind):
    print('-'*ind ,classes.__name__);
    for child in classes.__subclasses__():
        print_sub_classes(child , ind+3);
    return ;

ipt.getclasstree(ipt.getmro(BaseException));
print_sub_classes(BaseException , 0);
# Out:
#  BaseException
# --- Exception
# ------ TypeError
# --------- FloatOperation
# --------- MultipartConversionError
# ------ StopAsyncIteration
# ------ StopIteration
# ------ ImportError
# --------- ModuleNotFoundError
# --------- ZipImportError
# ------ OSError
# --------- ConnectionError
# ------------ BrokenPipeError
# ------------ ConnectionAbortedError
# ------------ ConnectionRefusedError
# ------------ ConnectionResetError
# --------------- RemoteDisconnected
# --------- BlockingIOError
# --------- ChildProcessError
# --------- FileExistsError
# --------- FileNotFoundError
# --------- IsADirectoryError
# --------- NotADirectoryError
# --------- InterruptedError
# ------------ InterruptedSystemCall
# --------- PermissionError
# --------- ProcessLookupError
# --------- TimeoutError
# --------- UnsupportedOperation
# --------- itimer_error
# --------- herror
# --------- gaierror
# --------- SSLError
# ------------ SSLCertVerificationError
# ------------ SSLZeroReturnError
# ...

# %%
# Question: What errors are defined in the ArithmeticError Class? Explain any two with an example?
ans = """
ArithmeticError is simply an error that occurs during numeric calculations.
It includes following errors:
1. OverFlowError.
2. ZeroDivisionError.
3. FloatingPointError.
Example for zeroDivisionError goes below.
"""
try:
    a = 5/0;
except (ZeroDivisionError , ArithmeticError) as E:
    print("Zero Division Error Occured:", E);
print("*************************************");
"""
Output:- Zero Division Error Occured: division by zero
"""
"""
Example for OverFlowError example
"""
i=10;
try:
    f = 3.0 **i;
    for i in range(100):
        print(i , f);
        f = f**3;
except (OverflowError , ArithmeticError) as E:
    print("Overflow:", E);
# Out:
# Zero Division Error Occured: division by zero
# *************************************
# 0 59049.0
# 1 205891132094649.0
# 2 8.727963568087712e+42
# 3 6.648731184578595e+128
# Overflow: (34, 'Numerical result out of range')

# %%
# Question: Why LoopKupError Class is used? Explain with an example keyerror and indexerror?
ans = """ 
LookUpError is the base class for errors raised when something can't be found.
The base class for the exceptios that are raised when a key or index used on a mapping
or sequence is invalid:IndexError, KeyError.
An IndexError is raised when a sequence reference is out of range.
The given code is rewritten as follows to catch the exception and find its type.
Example:
"""
import sys
try:
    foo = ['a','s','d','f','g'];
    print(foo[5]);
except IndexError as E:
    print(E);
    print(sys.exc_type);
# Out:
# list index out of range
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[26], line 13
#      12     foo = ['a','s','d','f','g'];
# ---> 13     print(foo[5]);
#      14 except IndexError as E:
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 16
#      14 except IndexError as E:
#      15     print(E);
# ---> 16     print(sys.exc_type);
#
# AttributeError: module 'sys' has no attribute 'exc_type'

# %%
# Explain importError. What is ModuleNotFoundError?
ans = """ 
    importError is raised when an import statement has trouble successfully importing the specified module.
    such a problem is due to an invalid or incorrect path.
    ModuleNotFoundError is a kind of Import Error, that will be raised whenever a module that is tried to be imported,
    is not found.
"""

# %%
# List down some best practices for exception handling in python?
ans = """ 
1. Use always a specific Exception, using Exception reference in except block is a bad practice.
If there is a chance of ZeroDivisionError to occur, let this class to handle the exception rather,
than making Exception class to handle the error.
2. Print always proper message.
3. Always to try to log your error in a separate file using logging module.
4. Always avoid to write a multiple exception handling.
5. Document all the errors.
6. Make sure all the resources are closed or cleaned up in finally block.
"""
